# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Adarsh\\MLProject\\End-to-End-Machine-Learning\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Adarsh\\MLProject\\End-to-End-Machine-Learning'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
            self,
            config_filepath = CONFIG_FILE_PATH,
            params_filepath = PARAMS_FILE_PATH,
            schema_filepath = SCHEMA_FILE_PATH):
        
            self.config = read_yaml(config_filepath)
            self.params = read_yaml(params_filepath)
            self.schema = read_yaml(schema_filepath)

            create_directories([self.config.artifacts_root])

    
    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
        )    
       
        return data_transformation_config

# %%
import os
from mlProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config


    ## Note: You can add diffrent data transformation techniques such as Scaler, PCA and all
    #  You can perform all kinds of EDA in ML cycle here before passing this data to the model 


    # I am only adding train_test_splitting cz this data is already is already clean up

    def train_test_spliting(self):
        data = pd.read_csv(self.config.data_path)

        # split the data into traning and test sets. (0.75, 0.25) split
        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index = False)

        logger.info("splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [2026-06-17 17:38:19,121: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-06-17 17:38:19,122: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-06-17 17:38:19,125: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-06-17 17:38:19,126: INFO: common: created directory at: artifacts]
# [2026-06-17 17:38:19,127: INFO: common: created directory at: artifacts/data_transformation]
# [2026-06-17 17:38:19,152: INFO: 4023367001: splited data into training and test sets]
# [2026-06-17 17:38:19,167: INFO: 4023367001: (857, 13)]
# [2026-06-17 17:38:19,168: INFO: 4023367001: (286, 13)]
# (857, 13)
# (286, 13)
